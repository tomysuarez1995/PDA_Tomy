# %% [markdown]
# # <center> <span style='color:#3A40A2 '> Ejercitación Módulo 2 </span></center>
# <hr style="border:1px solid gray"> </hr>
#
# La siguiente notebook contiene ejercitación del Módulo 2 de la Unidad Curricular ***"Programación Digital Avanzada"*** de la carrera de *Ingeniería Biomédica* de la UTEC.
#
# La *primera parte* y la *segunda parte* de esta notebook serán utilizadas para ejercitación. Por otro lado, la *tercera parte* será utilizada para el laboratorio del módulo y **se debe entregar** resuelta en una Jupyter Notebbok (puede ser esta misma). Además debe subirse la resolución a su repositorio de PDA en github.
#
# Profesor Adjunto: *Mag. Bioing. Baldezzari Lucas*
#
# <p style='text-align: right;'> V2022 </p>

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>
#
# ## <span style='color:#3A40A2 '> Primera parte </span>
#
# Investigue y responda.
#
# 1. ¿Qué sginifica que Python sea un lenguaje *no tipificado*.
# 2. Mencione algunas diferencias entre los tipos de datos *int* y *reales* en Python
# 3. Mencione algunas diferencias entre los tipos *tuplas*, *listas*, *string* y *diccionarios* en Python
# 4. ¿Qué es un *elemento* de una lista? ¿Cómo se puede acceder a un determinado elemento?
# 5. ¿Qué significa que un tipo de dato sea dinámico y mutable?
# 6. ¿Qué se entiende por *colección* o *collection* en Python? ¿Qué tipos de datos pertenecen a esta categoría?
# 7. ¿Qué significa *Aliasing* en el ámbito de Python?
# 8. ¿Qué entiende por parámetro o argumento de una función?
# 9. En las siguientes líneas de código, ¿cuál es la diferencia entre las variables s1 y s2?
#
# ```Python
# def saludar():
#     print("Buenas!")
#
# s1 = saludar()
# s2 = saludar
# ```
#
# 10. ¿Qué significa que las funciones *lambdas* pueden ser *anónimas*?
# 11. ¿Qué palabra reservada puede usarse para chequear si un elemento dentro se encuentra dentro de un set o una lista?
# 12. Observe el siguiente código y responda si es posible realizar dicha asignación. ¿Si? ¿No? ¿Por qué?
#
# ```Python
# miSet = {1,2,3, [1,2,3]}
# ```

# %%
#1. El lenguaje tipificado es aquel en el que el usuario debe declarar cada tipo de variable, por ejemplo int a=3
#y a esto python lo hace de manera muchas veces automatica.
#2. Int no cuenta con parte decimal como lo tienen los numeros reales, para trabajar con numeros reales existen los tipos
# de datos float.
#3. la diferencia entre tuplas y listas es que las primeras no son mutables al contrario de las listas, en el caso de los 
#diccionarios estos son mutables pero la diferencia es que los datos van en parejas, la clave y el valor, siendo la clave
# inmutable.
#4. Las listas son un tipo de arreglo de dato en python el cual tiene valores dentro y que se pueden acceder mediante comandos
#por ejemplo print lista[0], siendo 0 la posicion del elemento en la lista
#5. Significa que el dato puede modificarse y no hace falta declararlo como un tipo de variable.
#6. Son contenedores que se utilizan para almacenar colecciones de datos, por ejemplo, lista, dictar, establecer, tupla etc.
#7. Es cuando se le asigna otro nombre a una variable o un valor de una variable se asigna a otra variable
#8. es un valor que la función espera recibir cuando sea llamada para ejecutar una accion sobre si mismo.
#9. La diferencia es que la sintaxis del comando saludar sin el () es erroneo y generara un error en el codigo.
#10. Significa que no hace falta darles un nombre 
#11. la palabra reservada para eso se llama index
#12. No, ya que una lista no puede estar dentro de un diccionario o cadenas de texto, pero un diccionario o 
#cadena de texto si dentro de una lista.

# %%
def saludar():
    print("Buenas!")

s1 = saludar()
s2 = saludar
# Out:
# Buenas!

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>
#
# ## <span style='color:#3A40A2 '> Segunda parte </span>
#
# En esta parte deberá resolver los siguientes ejercicios.
#
# *NOTA:* Esta parte no debe entregarse.

# %% [markdown]
# #### <span style='color:#f95441'>Funciones para lectura de entradas desde teclado</span>
#
# Python ofrece algunas funciones *[built-in](https://docs.python.org/3/library/functions.html)* para solicitar a un usuario que ingrese algo por el teclado y leer dicha entrada, alguna de estas funciones son *[raw_input](https://python-reference.readthedocs.io/en/latest/docs/functions/raw_input.html)* e *[input()](https://docs.python.org/3/library/functions.html#input)*.
#
# Por ejemplo,
#
# ```Python
# nombre = input("¿Cuál es tu nombre?")
# print(f"Hola, {nombre}")
# ```

# %% [markdown]
# ### <span style='color:#f95441'>Ejercicios</span>

# %% [markdown]
# ##### Ejercicio 2.1
#
# Un polígono es regular si todos sus lados poseen la misma longitud y los ángulos internos de lados adyacentes son iguales. El área de un políguno regular puede ser calculado usando la siguiente fórmula, sonde $s$ es el largo de cada lado y $n$ es la cantidad de lados.
#
# $$   area = \frac{n\times s^2}{4\times \tan(\frac{\pi}{n})}  $$
#
# Escriba un programa que lea desde el teclado los valores de $s$ y $n$ y muestre el área del polígono.

# %%
## Resolución ejercicio 2.1

##TO DO
import math 
s = int(input("ingrese el largo del lado en el poligono: "))
n= int(input("ingrese cuantos lados tiene el poligono: "))

area= (n*(s*s))/(4*(math.tan(3.14/n)))
print ("el area del poligono es: " + str(area))
# Out:
# ingrese el largo del lado en el poligono: 5
# ingrese cuantos lados tiene el poligono: 5
# el area del poligono es: 43.04075902682102

# %% [markdown]
# ##### Ejercicio 2.2
#
# Escriba un programa que lea desde el teclado el valor de un entero de cuatro dígitos y muestre por pantalla la suma de los dígitos. Por ejemplo, si el usuario ingresa *1234* el programa debe mostrar *10*.

# %%
## Resolución ejercicio 2.2

##TO DO
cua= int(input("ingrese un valor entero de 4 digitos: "))  
sumando = 0
for suma in str(cua):  #le coloco str para que se pueda iterar 
    sumando += int(suma) #lo coloco como entero para que realice la operacion +=       
print(f"La suma de los 4 digitos es: {sumando}")
# Out:
# ingrese un valor entero de 4 digitos: 5555
# La suma de los 4 digitos es: 20

# %% [markdown]
# ##### Ejercicio 2.3
#
# Escriba un programa que calcule las raices de una función cuadrática.

# %%
## Resolución ejercicio 2.3

##TO DO
a=float(input("coloque el valor de a: "))
b=float(input("coloque el valor de b: "))
c=float(input("coloque el valor de c: "))
if a==0:
    print("no se puede dividir entre 0")
else:
    i=(b*b)-(4*a*c)
    if i<0:
        print("no hay raices reales")
    else:
        raiz1= (-b+((i)**-0.5))/(2*a) 
        raiz2= (-b-((i)**-0.5))/(2*a)      
    print(f"las raices son: {raiz1, raiz2}")
# Out:
# coloque el valor de a: 4
# coloque el valor de b: -5
# coloque el valor de c: -3
# las raices son: (0.6396301433995163, 0.6103698566004837)

# %% [markdown]
# ##### Ejercicio 2.4
#
# Ruido |dB |
# -----|-----|
# Martillo neumático |130|
# Desmalezadora a nafta|106|
# Alarma reloj|70|
# Tranquilo|40|
#
# Escriba un programa que reciba un nivel de ruido en decibeles $dB$. Si el nivel de ruido coincide con uno de los ruidos de la tabla anterior, el programa debe informar a qué se debe. En el caso de que el nivel de ruido este entre alguno de los dos niveles, el programa debe informar entre que ruidos se encuentra el nivel ingresado. Además, el programa implementado debe dar mensajes adecuados si los sonidos estan por encima del valor máximo o por debajo del mínimo.

# %%
## Resolución ejercicio 2.4

##TO DO
ruido= float (input("ingrese el dB del ruido escuchado: "))
ruidos= {"martillo neumatico": 130, "desmalezadora a nafta": 106, "alarma reloj": 70, "tranquillo":40}

for x, y in ruidos.items():
    if ruido == y:
        print(f"el ruido pertenece a: {x}")
        break
    else :
        print("es menor al minimo")
#no pude, me estrese y me fui a dormir, nota: preguntar luego como se soluciona
# Out:
# ingrese el dB del ruido escuchado: 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12308/432386643.py in <module>
#      11         print(f"el ruido pertenece a: {x}")
#      12         break
# ---> 13     elif ruido< y(0):
#      14         print("es menor al minimo")
#      15     elif ruido>y(4):
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ##### Ejercicio 2.5
#
# Utilizando *enumerate()* implemente un programa que imprima las letras pertenecientes a los índices divisibles por 3 del string *abcdefghijklmnopqrstuvwxyz*. Empezar a contar desde 1.

# %%
### Resolución Ejercicio 2.5

abc = "abcdefghijklmnopqrstuvwxyz"
listabc= list(abc)
for co, di in enumerate(listabc, start=1):
    if co%3==0:
        print (f"las letras de los indices son: {di}")
##TO DO
# Out:
# las letras de los indices son: c
# las letras de los indices son: f
# las letras de los indices son: i
# las letras de los indices son: l
# las letras de los indices son: o
# las letras de los indices son: r
# las letras de los indices son: u
# las letras de los indices son: x

# %% [markdown]
# ##### Ejercicio 2.6
#
# Las posiciones en un tablero de ajedrez se identifican con letras y números. Las letras indican las columnas mientras que los números indican las filas, como la imágen debajo.
#
# <img src="chessboard.png" width=250 height=250 />
#
# Escriba un programa que lea desde el teclado una coordenada del tablero (ej. 'a3') y devuelva si el casillero es de color blanco o negro. Asuma que todas las entradas son correctas, es decir, **no** es necesario realizar un chequeo de errores (veremos más adelante cómo hacer esto con *try* y *except*).

# %%
## Resolución ejercicio 2.6
#me dio pereza, luego pregunto
##TO DO

# %% [markdown]
# ##### Ejercicio 2.7
#
# Escriba un programa que convierta números binarios a números decimales. El programa debe leer desde el teclado un número binario en forma de string y computar el equivalente en decimal. El número calculado debe mostrarse en un mensaje.

# %%
## Resolución ejercicio 2.7

##TO DO
numBin= input("ingrese un numero en binario: ")
num_10 = 0
for pos, dig  in enumerate(numBin[::-1]):
    num_10 += int (dig)*2** pos
print (f"su numero en decimal es: {num_10}")
# Out:
# ingrese un numero en binario: 100111
# su numero en decimal es: 39

# %% [markdown]
# ##### Ejercicio 2.8
#
# Escriba un programa que determine si un número entero $n$ es *perfecto*. Un número es perfecto cuando la suma de sus propios divisores da el mismo número.
#
# Por ejemplo, el *6* es un número perfecto, ya que la suma de sus divisores es $1+2+3 = 6$.

# %%
## Resolución ejercicio 2.8

##TO DO        
def numPerfectWin(numb):
    sum_a = 0
    for h in range(1, numb):
        if numb% h == 0:
            sum_a += h
    return sum_a ==numb
 
numb = int(input("introduzca un numero:"))
 
if numPerfectWin(numb): #si pongo sum_a me toma como que el valor lo existe, por eso en return tengo que poner ==numb, porque?
    print(f"el numero {numb} es perfecto")
else:
    print(f"el numero {numb} no es perfecto")
# Out:
# introduzca un numero:6
# el numero 6 es perfecto

# %% [markdown]
# ### <span style='color:#4BB58D '>Funciones</span>

# %% [markdown]
# ##### Ejercicio 2.9
#
# Implemente una función que devuelva el factorial de un número entero n.

# %%
## Resolución ejercicio 2.9

##TO DO
#from math import factorial
n1= int(input("ingrese un numero para calcular su factorial: "))
#print(f"el factorial de {n1} es {factorial(n1)}") #esta es la forma mas facil pero bueno, habia que hacer una funcion
fact=1 #esto pa que la multiplicacion no sea 0
if n1!=0:
    for w in range(1, n1+1): #esto tuve que ponerlo asi xq por la logica que tengo con el if de n1!=0 no deberia colocarlo pero si me lo requirio o daba error
        fact=fact*w
    print(f"el factorial de {n1} es {fact}")
else:
    print("el numero es 0, no se puede calcular su factorial")
# Out:
# ingrese un numero para calcular su factorial: 6
# el factorial de 6 es 720

# %% [markdown]
# ##### Ejercicio 2.10
#
# Implemente una función que reciba una lista de números enteros y devuelva una nueva lista pero sin los valores repetidos.
#
# NOTA: No usar funciones *built-in*.

# %%
## Resolución ejercicio 2.10

##TO DO
darthVader= []
luke=[]
while True:
    force= input("ingrese un numero para la lista: ")
    darthVader.append(force)
    for anakin in darthVader:
        if anakin not in luke:
            luke.append(force)
            print(luke)
    yoda= input("desea agregar otro numero? (y/n)")
    if yoda == "y":
        continue 
    elif yoda == "n":
        print(f"fin del agregado de datos, lista final {luke} ")
        break
#The Force is Whit You
# Out:
# ingrese un numero para la lista: 9
# ['9']
# desea agregar otro numero? (y/n)y
# ingrese un numero para la lista: 5
# ['9', '5']
# desea agregar otro numero? (y/n)y
# ingrese un numero para la lista: 0
# ['9', '5', '0']
# desea agregar otro numero? (y/n)y
# ingrese un numero para la lista: 15
# ['9', '5', '0', '15']
# desea agregar otro numero? (y/n)y
# ingrese un numero para la lista: 5
# desea agregar otro numero? (y/n)m
# ingrese un numero para la lista: 9
# desea agregar otro numero? (y/n)n
# fin del agregado de datos, lista final ['9', '5', '0', '15']

# %% [markdown]
# ##### Ejercicio 2.11
#
# Implemente una función que reciba como argumento un año y retorne *True* si el año es bisiesto, caso contrario que retorne *False.
#
# Para saber si un año es bisiesto tenga en cuenta estos puntos:
# - Cualquier año divisible por 400 es bisiesto.
# - De los años restantes, cualquiera que sea divisible por 100 **no** es bisiesto.
# - De los años restantes, cualquiera que sea divisible por 4 es un año bisiesto.

# %%
## Resolución ejercicio 2.11

##TO DO
año= int (input("ingrese un año: "))
print(f"el año { año} es bisiesto" if not año % 4 and (año % 100 or not año % 400) else f"el año {año} no es bisiesto")
#if año%4==0 es lo mismo que if not año %4, de igual forma if año %100 es lo mismo que if año%100!=0
# Out:
# ingrese un año: 1995
# el año 1995 no es bisiesto

# %% [markdown]
# ##### Ejercicio 2.13
#
# Implemente una función que reciba como parámetro una lista de números (enteros o flotantes) y retorne la *mediana*.

# %%
## Resolución ejercicio 2.12

##TO DO

# %% [markdown]
# ##### Ejercicio 2.12
#
# Impmemente una función que retorne el máximo de una lista de números. No utilizar funciones *built-in*.

# %%
## Resolución ejercicio 2.13

##TO DO
listaS=[]
mxVal = None
while True:
    num7= float(input("ingrese un numero: "))
    listaS.append(num7)
    nix= input("desea agregar otro numero?: (y/n)")
    if nix == "y":
        continue
    elif nix=="n":
        for nm in listaS:
            if (mxVal is None or nm > mxVal):
                mxVal = nm
        print(f"el valor maximo es: {nm}")
        break
# Out:
# ingrese un numero: 56.3
# desea agregar otro numero?: (y/n)y
# ingrese un numero: 89
# desea agregar otro numero?: (y/n)y
# ingrese un numero: 89.1
# desea agregar otro numero?: (y/n)n
# el valor maximo es: 89.1

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>
#
# ## <span style='color:#3A40A2 '> Tercera parte </span>
#
# **Se habilitará para el laboratorio.**

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>
#
# ##  <span style='color:#3A40A2 '>FIN</span>
